# %% [markdown]
# # Python для анализа данных
#
# ## API

# %% [markdown]
# ## API YouTube
#
# + [Инструкция](https://sphenoid-aluminum-1ba.notion.site/API-YouTube-a1e2552472c246d295b6f1d1dbce5dcb) по получению ключа API YouTube
# + Официальная [документация](https://developers.google.com/youtube/v3/docs) к API YouTube
# + Статья на Хабр. [Что такое API?](https://habr.com/ru/post/464261/)
# + Статья на Хабр. [Что такое JSON](https://habr.com/ru/post/554274/)
#
# API (Application programming interface) — это контракт, который предоставляет программа. Иными словами, это функции от разработчика, которые предоставлены в наше использование и распоряжение.
#
# Сегодня попробуем потыкаться в API YouTube и вытащить какую-нибудь информацию. Но для этого нам нужен собственно доступ к API (ключ). Как его получить, можно узнать в [инструкции](https://sphenoid-aluminum-1ba.notion.site/API-YouTube-a1e2552472c246d295b6f1d1dbce5dcb).

# %%
# !pip install google-api-python-client
import googleapiclient.discovery as api

# %%
# Поскольку API-ключи привязаны к личным аккаунтам и хранят эту связь, не стоит выкладывать в открытый доступ ваш ключ.
# Я создала отдельный файл youtube_key.py, где задала константу YT_API_KEY и положила свой токен в виде строки.
# Получить свой токен: https://sphenoid-aluminum-1ba.notion.site/API-YouTube-a1e2552472c246d295b6f1d1dbce5dcb

from youtube_key import *
key = YT_API_KEY

# %%
# key = 'ВАШ КЛЮЧ'
youtube = api.build('youtube', 'v3', developerKey = key)

# %% [markdown]
# Далее используем запрос, который предлагается нам в самой документации. Этот тот момент, где вам не нужно задумываться о том, почему метод называется так и почему он хочет определенные параметры — просто так придумал разработчик.
#
# ### Видео по опеределенному запросу
#
# Например, в самой [документации](https://developers.google.com/youtube/v3/docs/search/list?hl=en) про параметр `part` сказано Set the parameter value to snippet.
#
# `maxResults` — сколько видео (максимально можно 50, но, спойлер, это ограничение можно обойти) \
# `q` — запрос, который мы ищем \
# `type` — пока мы ищем видео, но можно и каналы \
# `order` — по релевантности (его можно убрать) \
# Это все наш запрос с помощью метода .`search()`. Выгружаем его командой `.execute()`.

# %%
request_search = youtube.search().list(
    part = "snippet",
    maxResults = 10,
    q = "API with Python",
    type = 'video',
    order = 'relevance')

response_search = request_search.execute()
response_search
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'WeCP6FUeuMQITZ03z741czsmYog',
#  'nextPageToken': 'CAoQAA',
#  'regionCode': 'RU',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 10},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '2Jp-NA9qeDhCQXj-KXnbUm9dgp0',
#    'id': {'kind': 'youtube#video', 'videoId': 'zsYIw6RXjfM'},
#    'snippet': {'publishedAt': '2023-05-23T13:00:53Z',
#     'channelId': 'UC4JX40jDee_tINbkjycV4Sg',
#     'title': 'Create A Python API in 12 Minutes',
#     'description': 'Rapidly build and deploy APIs in seconds with DreamFactory ! https://bit.ly/3M1TAP7 Are you learning programming and ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Tech With Tim',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-23T13:00:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Y7XInBVe7JGvsZgKVsD7n61CAxY',
#    'id': {'kind': 'youtube#video', 'videoId': '0sOvCWFmrtA'},
#    'snippet': {'publishedAt': '2021-11-01T13:11:23Z',
#     'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'title': 'Python API Development - Comprehensive Course for Beginners',
#     'description': 'Learn Python API development in one of the most comprehensive courses ever on the topic. You will build a full-fledged API in ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0sOvCWFmrtA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0sOvCWFmrtA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0sOvCWFmrtA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'freeCodeCamp.org',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-01T13:11:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3lOW-qpARVju59ev0Gpkext2sf4',
#    'id': {'kind': 'youtube#video', 'videoId': '0x0hOdvhCXU'},
#    'snippet': {'publishedAt': '2019-10-10T07:52:52Z',
#     'channelId': 'UCGuhp4lpQvK94ZC5kuOZbjA',
#     'title': 'Урок 4. Python. Быстрый старт. Изучаем API сервиса',
#     'description': 'Подробнее о курсе "Python. Полное руководство": https://webformyself.com/python/ Итак, немного познакомившись с Python, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0x0hOdvhCXU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0x0hOdvhCXU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0x0hOdvhCXU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'WebForMySelf',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-10-10T07:52:52Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'i7FZmBI0W3oD1JpO9EbldpiTyns',
#    'id': {'kind': 'youtube#video', 'videoId': 'hpc5jyVpUpw'},
#    'snippet': {'publishedAt': '2019-11-02T14:00:09Z',
#     'channelId': 'UCF1dnm4HfA9LYQo9fVU5RKQ',
#     'title': 'Working with APIs in Python - Code in 10 Minutes',
#     'description': 'In this video, I teach you the basics of APIs & how to work with them in Python. --- Get access to full VideoLab courses at: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hpc5jyVpUpw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hpc5jyVpUpw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hpc5jyVpUpw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'VideoLab',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-11-02T14:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-MA2J859tqLPYvh3fKTT69dqnpU',
#    'id': {'kind': 'youtube#video', 'videoId': 'qbLc5a9jdXo'},
#    'snippet': {'publishedAt': '2020-11-19T20:27:58Z',
#     'channelId': 'UCZUyPT9DkJWmS_DzdOi7RIA',
#     'title': 'REST API Crash Course - Introduction + Full Python API Tutorial',
#     'description': 'FREE Courses (100+ hours) - https://calcur.tech/all-in-ones Python Course - https://calcur.tech/python-courses Timestamps: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qbLc5a9jdXo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qbLc5a9jdXo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qbLc5a9jdXo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Caleb Curry',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-11-19T20:27:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Ci3lQuyJPhI_USiP-ruP_vmzAyc',
#    'id': {'kind': 'youtube#video', 'videoId': '5ZMpbdK0uqU'},
#    'snippet': {'publishedAt': '2021-01-27T08:30:00Z',
#     'channelId': 'UCuudpdbKmQWq2PPzYgVCWlA',
#     'title': 'Create your own Public API in Python Tutorial',
#     'description': "Hey guys! In this video I'll be showing you how you can create your own API in Python. This is perfect for testing something on ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5ZMpbdK0uqU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5ZMpbdK0uqU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5ZMpbdK0uqU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Indently',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-01-27T08:30:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2ASmPvV_LIbKescp9K_am5zAHSw',
#    'id': {'kind': 'youtube#video', 'videoId': 'fXa_2rllZTI'},
#    'snippet': {'publishedAt': '2022-06-02T13:45:01Z',
#     'channelId': 'UCSTYGpIpMIiQPspjLplB6Ow',
#     'title': 'Что такое API?',
#     'description': 'Получи высокооплачиваемые знания в Merion Academy! https://bit.ly/3taDcSE API расшифровывается как Application ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fXa_2rllZTI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fXa_2rllZTI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fXa_2rllZTI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Merion Academy - доступное IT образование',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-02T13:45:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'QiAdXIXC4Y5B0k_zng4_O-px6SI',
#    'id': {'kind': 'youtube#video', 'videoId': '-ykeT6kk4bk'},
#    'snippet': {'publishedAt': '2021-05-29T15:00:00Z',
#     'channelId': 'UC4JX40jDee_tINbkjycV4Sg',
#     'title': 'Python FAST API Tutorial',
#     'description': 'Welcome back to my channel! In this video, I will be showing you FastAPI which is a Python framework. As the name suggests, this ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-ykeT6kk4bk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-ykeT6kk4bk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-ykeT6kk4bk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Tech With Tim',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-05-29T15:00:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'A43PJ-gHVQkWFQhOLaPEKrHQZ7Q',
#    'id': {'kind': 'youtube#video', 'videoId': '_k22Bs3zYyA'},
#    'snippet': {'publishedAt': '2023-07-04T16:10:08Z',
#     'channelId': 'UCbjozK_PYCTLEluFlrJ8UZg',
#     'title': 'FULL STACK PYTHON Offline Training @ DURGASOFT',
#     'description': 'FULL STACK PYTHON Offline Training @ DURGASOFT ================================================== FULL ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_k22Bs3zYyA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_k22Bs3zYyA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_k22Bs3zYyA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Durga Software Solutions',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-04T16:10:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'drjsaqgAN1xwcyXgE6YjRY49yiY',
#    'id': {'kind': 'youtube#video', 'videoId': '-oPuGc05Lxs'},
#    'snippet': {'publishedAt': '2021-06-20T17:00:00Z',
#     'channelId': 'UC8tgRQ7DOzAbn9L7zDL8mLg',
#     'title': 'Working With APIs in Python - Pagination and Data Extraction',
#     'description': 'In this video I will show you how to work with an API using Python to extract data. Using the requests module we can request the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-oPuGc05Lxs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-oPuGc05Lxs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-oPuGc05Lxs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'John Watson Rooney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-06-20T17:00:00Z'}}]}

# %% [markdown]
# Это просто словарь! А с ними вы работать уже умеете.
#
# К слову, использование этого API **бесплатно**, но не бесконечно. Есть определенный лимит для одного ключа —10.000 у.е в день (например, запрос видео выше стоил нам 100 у.е). Подробнее об этом можно почитать в самой документации. Такое придумано в API YouTube (для других API может быть что-то свое или вообще не быть лимита).
#
# Посмотрим, какие тут есть ключи:

# %%
response_search.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'regionCode', 'pageInfo', 'items'])

# %% [markdown]
# Из них нас интересуют только `nextPageToken`, `pageInfo`, `items`.
#
# `nextPageToken` — адрес следующей страницы нашего поиска; до тех пор пока он есть в выдаче, мы можем собирать данные. \
# `pageInfo` — сколько всего результатов и сколько всего результатов по нашему запросу. Если всего результатов очень много, то все вы не получите (так уж устроен API YouTube); можно исхитриться и в цикле делать запрос от и до определенной даты. \
# `items` — все видео, которые мы нашли (у нас их десять).

# %%
print(type(response_search['items'])) # это список! 
print(len(response_search['items']))  # наши десять видео
# Out:
# <class 'list'>
# 10

# %% [markdown]
# Вытащим самое первое видео и посмотрим, что там.

# %%
response_search['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '2Jp-NA9qeDhCQXj-KXnbUm9dgp0',
#  'id': {'kind': 'youtube#video', 'videoId': 'zsYIw6RXjfM'},
#  'snippet': {'publishedAt': '2023-05-23T13:00:53Z',
#   'channelId': 'UC4JX40jDee_tINbkjycV4Sg',
#   'title': 'Create A Python API in 12 Minutes',
#   'description': 'Rapidly build and deploy APIs in seconds with DreamFactory ! https://bit.ly/3M1TAP7 Are you learning programming and ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Tech With Tim',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2023-05-23T13:00:53Z'}}

# %%
response_search['items'][0].keys()
# Out:
# dict_keys(['kind', 'etag', 'id', 'snippet'])

# %% [markdown]
# Тут нас интересуют ключи `id` и `snippet`.
#
# * в `id` записано `'videoId'` (оно нам нужно, чтобы вытащить информацию о конкретном видео, например, статистику по лайкам или комментарии)
# * `snippet` содержит основную информацию о видео (id канала, заголовок, описание).

# %%
response_search['items'][0]['id']['videoId']
# Out:
# 'zsYIw6RXjfM'

# %% [markdown]
# К слову, само видео можно посмотреть так: https://www.youtube.com/watch?v=zsYIw6RXjfM. Обратите внимание, куда именно подставлятся наше id.

# %% [markdown]
# ## Комментарии к определенному видео
#
# Например, можно забрать комментарии определенного видео (а в перспективе — посмотреть их тональность). Поможет нам в этом метод `.commentThreads()`.

# %%
comment_request = youtube.commentThreads().list(
    part = 'snippet',
    videoId = "zsYIw6RXjfM"
)

comment_response = comment_request.execute()
comment_response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': '8P2k5uCmOoSwQicYKaVqV1-Dd80',
#  'nextPageToken': 'QURTSl9pM05RTUZUQUJHbjhqYWYydUNsZnp1TF8tVlFNdXlhQXJBeVJ6bm5vSXkzb1VKc3lpMDZBNlFCM2ZTdndmenh1YXR2ZWRfXzJJNUcxMHcwUmFoWk14cWlKUm11',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'nDodmFc5JqjkcNlIhgU5cbboQsU',
#    'id': 'Ugwv2of8WoJe24fHanB4AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'y2Z87uU69Ux9yL3CBeSPkp_pYLw',
#      'id': 'Ugwv2of8WoJe24fHanB4AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'Rapidly build and deploy APIs in seconds with DreamFactory ! <a href="https://bit.ly/3M1TAP7">https://bit.ly/3M1TAP7</a>',
#       'textOriginal': 'Rapidly build and deploy APIs in seconds with DreamFactory ! https://bit.ly/3M1TAP7',
#       'authorDisplayName': 'Tech With Tim',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqPB8zsV8e0A21azF81MeCaAsmHAaT1_9L6xZek4zw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC4JX40jDee_tINbkjycV4Sg',
#       'authorChannelId': {'value': 'UC4JX40jDee_tINbkjycV4Sg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 8,
#       'publishedAt': '2023-05-23T13:46:10Z',
#       'updatedAt': '2023-05-23T13:46:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '_faOkiau5AYs2WqoH5OGAA1EOXo',
#    'id': 'UgzIBw1AOI50fxesDhB4AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'AOIctRpNt7blnc0599nLDnoY6s4',
#      'id': 'UgzIBw1AOI50fxesDhB4AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'not able to install flask tried changing the virtual environment as well<br>someone if faced the same issue please help',
#       'textOriginal': 'not able to install flask tried changing the virtual environment as well\nsomeone if faced the same issue please help',
#       'authorDisplayName': 'himanshu nanda',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqOK2kWNkJK7irTcGbmXBjrdUxWjWSTrSyrJ7N-pGQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCboqV7yFtsrYGiaBC1sjv4Q',
#       'authorChannelId': {'value': 'UCboqV7yFtsrYGiaBC1sjv4Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-06-30T17:46:23Z',
#       'updatedAt': '2023-06-30T17:46:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5mK1JZ2NrhFesUawxv7VPNmclL4',
#    'id': 'UgwOUtXWJvzjlkFRzQx4AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'iqSgAbyHcJkYzsv2sslGB_9Tx3Q',
#      'id': 'UgwOUtXWJvzjlkFRzQx4AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'An API is just an interface of callable functions. It can be a code library that simplifies some complex tasks, a web API (which is what this video talks about) or a bunch of functions that a running process on your computer exposes for other programs to interact with',
#       'textOriginal': 'An API is just an interface of callable functions. It can be a code library that simplifies some complex tasks, a web API (which is what this video talks about) or a bunch of functions that a running process on your computer exposes for other programs to interact with',
#       'authorDisplayName': 'lurviQ',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqOt9hmxzfUkBtmI9AY6grRqf9FiUCgPpGKLdw7j6w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCQCUBEIBhH2Vx7WJbxN7lFg',
#       'authorChannelId': {'value': 'UCQCUBEIBhH2Vx7WJbxN7lFg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-06-29T20:26:14Z',
#       'updatedAt': '2023-06-29T20:26:14Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'RYlSBfCGa5bf4fFqpSmzYjMlVUs',
#    'id': 'UgxGwGhQuLyF1BdyJu14AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'zs5L48jp9E8uEY6pDLuTP2046tw',
#      'id': 'UgxGwGhQuLyF1BdyJu14AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'Thanks so much',
#       'textOriginal': 'Thanks so much',
#       'authorDisplayName': 'Seriously Tho',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqM-LGjUiRHOPM3B7omI-YSRlC6AYxP4JhVx04-xyi7zwxlr8yfTbV0pN9llRu2j=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCLL5kfj_KeoXug85_A8uKBA',
#       'authorChannelId': {'value': 'UCLL5kfj_KeoXug85_A8uKBA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-06-25T09:46:26Z',
#       'updatedAt': '2023-06-25T09:46:26Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'qIfh8vIQiOBrm_r17hU0jjR2KOE',
#    'id': 'Ugzr0bdDBjBtxm-HP1F4AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'PYBqne1icRpOlVEcnYTAZWL14eA',
#      'id': 'Ugzr0bdDBjBtxm-HP1F4AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'Great video like always Tim 👍🏽🍷',
#       'textOriginal': 'Great video like always Tim 👍🏽🍷',
#       'authorDisplayName': 'Bon Voyage',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqNoceMy8rCgqOPxxkJWzgFmuZV1oEf6Sx7vodb6=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCUj5FvnPQKDIVUyVXOkilKA',
#       'authorChannelId': {'value': 'UCUj5FvnPQKDIVUyVXOkilKA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-06-22T21:11:14Z',
#       'updatedAt': '2023-06-22T21:11:14Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'knJq5_ZVEzN8Ws_BHHBHXBYy9OY',
#    'id': 'Ugzx5ACE8bW7FwyRxR94AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '21GO8V9GJv31giACwA5AXE33C08',
#      'id': 'Ugzx5ACE8bW7FwyRxR94AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'instead of saying &quot;underscore underscore&quot; you can say &quot;dunder&quot; which is double underscore',
#       'textOriginal': 'instead of saying "underscore underscore" you can say "dunder" which is double underscore',
#       'authorDisplayName': 'mostafa ghobashy',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqOMDCiKLHsQA088lBxOvuOaeCVSin4ULSzqvg1kn844A5Y1SdDQJCGJGBkqhna0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCQ8l2LWUacPrH-yv9_HupWw',
#       'authorChannelId': {'value': 'UCQ8l2LWUacPrH-yv9_HupWw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-06-20T08:39:59Z',
#       'updatedAt': '2023-06-20T08:39:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '1mCtfcrtq06VyWkgE6zCvGw0tLg',
#    'id': 'UgzuSaI5xuqvOEg6h6J4AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'C6mLRf9Kxe0rsQCrXh4--JFj-wc',
#      'id': 'UgzuSaI5xuqvOEg6h6J4AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'vary good video... Thanks',
#       'textOriginal': 'vary good video... Thanks',
#       'authorDisplayName': 'carlos eduardo de souza',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqM75qJDxnYa6t7Q-W4I76Op3vDocDZ58O8z-qAFrg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCRtS8coaSqZFw-RRAQLZrPg',
#       'authorChannelId': {'value': 'UCRtS8coaSqZFw-RRAQLZrPg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-06-15T20:30:03Z',
#       'updatedAt': '2023-06-15T20:30:03Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'hECvtwi_KUs1hJbOGO8mxfajesg',
#    'id': 'UgwfYGbMwjSv_Cr5p854AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'SBDAJ8CP2UsobtU9qfjhfIEW9Z4',
#      'id': 'UgwfYGbMwjSv_Cr5p854AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'api is not only for database, can be instructing other devices to do something, might not even need a reply.',
#       'textOriginal': 'api is not only for database, can be instructing other devices to do something, might not even need a reply.',
#       'authorDisplayName': 'Jyv Ben',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqPjFDrHzHQ01iDeJKpw_8Q3A2Buc-daUkMI7Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCwb-5YjCNwSK_dhS00QObWg',
#       'authorChannelId': {'value': 'UCwb-5YjCNwSK_dhS00QObWg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-06-11T17:33:34Z',
#       'updatedAt': '2023-06-11T17:33:34Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'kr8zd1AKB6SGAHbPWpTiZp_iPzc',
#    'id': 'Ugwdr3HeQv1Ek7UwnR54AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'akiMge2P_jFcvD0ba_j0GeOBf8o',
#      'id': 'Ugwdr3HeQv1Ek7UwnR54AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'Great vid thanks. I think you might have missed some info if you can confirm. When you demo the GET request you&#39;re using the id:123, however we don&#39;t set that up so we can&#39;t repeat the steps as you have as you have presumably already created a user in this scenario?',
#       'textOriginal': "Great vid thanks. I think you might have missed some info if you can confirm. When you demo the GET request you're using the id:123, however we don't set that up so we can't repeat the steps as you have as you have presumably already created a user in this scenario?",
#       'authorDisplayName': 'Stuart Mould',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqMtqILVJ8jZxXHq9Zdv7ptjNLx-ToT3h-zamGTwoQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCOL65qONgcv2EGbhzBuOd1g',
#       'authorChannelId': {'value': 'UCOL65qONgcv2EGbhzBuOd1g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-06-09T20:18:28Z',
#       'updatedAt': '2023-06-09T20:18:28Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'RTfwqBEYqVUnnn7_lip2K6hjIIY',
#    'id': 'Ugzl0Nivr0T8vAM213R4AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'sF_O-D3qHuttks1JLBzal5gW2lU',
#      'id': 'Ugzl0Nivr0T8vAM213R4AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'Use fast api and create apis even faster',
#       'textOriginal': 'Use fast api and create apis even faster',
#       'authorDisplayName': 'TheLifeHacker Pro',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqNvs8N4sXZbGqbnETik8Y_Eyx84-9_Ox2uxvg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCvbgiUqIb7K98FudVADsvOQ',
#       'authorChannelId': {'value': 'UCvbgiUqIb7K98FudVADsvOQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-06-06T16:44:05Z',
#       'updatedAt': '2023-06-06T16:44:05Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '2dzicH8aZSXm26amnh-Ajk9GFu8',
#    'id': 'Ugwma7H_g27yCnKP0R94AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'UXHnYoYxywt8Du4XbXYJWge_U-0',
#      'id': 'Ugwma7H_g27yCnKP0R94AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'Thank you  so much for  this video',
#       'textOriginal': 'Thank you  so much for  this video',
#       'authorDisplayName': 'pungushe 1256',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqN_wNRhQM1f3nxfSmw3ti1bXXxBHPVkxEm12w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCqeYx7t2_B6RGWYOTHEecXQ',
#       'authorChannelId': {'value': 'UCqeYx7t2_B6RGWYOTHEecXQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-06-05T14:53:22Z',
#       'updatedAt': '2023-06-05T14:53:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '6a20z94wryCuFSPRVSBibsMOpf4',
#    'id': 'UgxsSaUb5XDYrwF58fl4AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'gABgVPcgFEtnqNOe8oNMiIbDl1Q',
#      'id': 'UgxsSaUb5XDYrwF58fl4AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'nice video and the beard suits you well.',
#       'textOriginal': 'nice video and the beard suits you well.',
#       'authorDisplayName': 'Amir Mirzababapour',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqPLgAcl1SDH3itBbGPvwsXwnCDPn75b_W0qtA8s=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC1d4Yzb-TKWeooPKk2Rgzmg',
#       'authorChannelId': {'value': 'UC1d4Yzb-TKWeooPKk2Rgzmg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-06-05T07:53:47Z',
#       'updatedAt': '2023-06-05T07:53:47Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xqCpBt_JhhmTsGNuBmYcDzM9F3c',
#    'id': 'UgxYkFtrLsdKkT346aB4AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '71Khgpcg8pvFTQPBB6CQ-X5NgX0',
#      'id': 'UgxYkFtrLsdKkT346aB4AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'i tried the get part and got an error :<br>The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.',
#       'textOriginal': 'i tried the get part and got an error :\nThe requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.',
#       'authorDisplayName': 'Damilola Asepo',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqO_3kL5KClkZ-qTDwYKJHwZ-rJKP6Mv0Zw2gw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCNrKfVKgGhoUkb23NIV8HiA',
#       'authorChannelId': {'value': 'UCNrKfVKgGhoUkb23NIV8HiA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2023-06-05T00:45:35Z',
#       'updatedAt': '2023-06-05T00:45:35Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'XIMtlaaB-3i7itILSCtNt2sodis',
#    'id': 'UgyCDaX-ppqka4OCTr94AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'oUv8DzPRBvdTka6iB85vxFX91T8',
#      'id': 'UgyCDaX-ppqka4OCTr94AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': '6 Years experience in every aspect computing and technology but somehow I never came across API development, very interesting. I&#39;ve just been calling and calling them but never writing them',
#       'textOriginal': "6 Years experience in every aspect computing and technology but somehow I never came across API development, very interesting. I've just been calling and calling them but never writing them",
#       'authorDisplayName': 'ASMR Sensations',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-RIQklZbYneEF7aMCHR4wKZanyA9VLYdmHXteKE0PWYjSKevu-eCwNn3jNEashmCKKIhF7O3=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCaXrLXVzrQHEeEA5_9nzUVg',
#       'authorChannelId': {'value': 'UCaXrLXVzrQHEeEA5_9nzUVg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-06-03T00:00:22Z',
#       'updatedAt': '2023-06-03T00:00:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '0H0SQWdLdmGsLPqnt4WPp7DuO00',
#    'id': 'Ugy0fI2Tj4SlvR4ktU54AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'BIDzEUf-oyRsqJbD5IMVVZ0pAsQ',
#      'id': 'Ugy0fI2Tj4SlvR4ktU54AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'you got old but stil very good',
#       'textOriginal': 'you got old but stil very good',
#       'authorDisplayName': 'The Beast',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqN17t8FJLJqsPxCTtfBd5Q20mapVC5TPbCfMMiFyg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCWbA_HGC18KeW3Zc-T6HguQ',
#       'authorChannelId': {'value': 'UCWbA_HGC18KeW3Zc-T6HguQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-28T15:20:13Z',
#       'updatedAt': '2023-05-28T15:20:13Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'M5icxqk209RSrYVEYWhMbL_GqPY',
#    'id': 'UgzLyrqUDSkXpyEMUAF4AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'W4mT4x44Y4iU_xKPGH-9xpPDdB4',
#      'id': 'UgzLyrqUDSkXpyEMUAF4AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'Why do we need to specify mathods = [&quot;POST&quot;] for create user method apart from signifying that we want to write to database? Is there an actual utility? As far as i understand this method would be able to do its job even if you hadn&#39;t specified method',
#       'textOriginal': 'Why do we need to specify mathods = ["POST"] for create user method apart from signifying that we want to write to database? Is there an actual utility? As far as i understand this method would be able to do its job even if you hadn\'t specified method',
#       'authorDisplayName': 'Dimitrios Ladakis',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqO8uMA7c_Z3oq44fMqYTvG17nWiHk6R2HQdHZTS=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCJ67vImpmAmXea2A_FH3UOA',
#       'authorChannelId': {'value': 'UCJ67vImpmAmXea2A_FH3UOA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-27T12:46:30Z',
#       'updatedAt': '2023-05-27T12:46:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'mYm_Y7FrKuE8eurDZiGvsLOE720',
#    'id': 'UgwqsIsgy15bWPA6G4l4AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'W8-k9bSCfvrVZa9cg3T7QaKBrKY',
#      'id': 'UgwqsIsgy15bWPA6G4l4AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'sir can you make a vid , about creating minecraft in python using ursina engine!',
#       'textOriginal': 'sir can you make a vid , about creating minecraft in python using ursina engine!',
#       'authorDisplayName': 'Reshidaar B',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/kX43augFuAvb7yaxv-HmJbb9fznj2pT81IvgNastzr8myxy6Qge-0KD2MRLzWUoHP4FJnhMNngo=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC0K30-mhgg63OBZxVNngnAg',
#       'authorChannelId': {'value': 'UC0K30-mhgg63OBZxVNngnAg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-27T05:56:51Z',
#       'updatedAt': '2023-05-27T05:57:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'RteQjdSATS9PGJWWiUzIXnOhpYQ',
#    'id': 'Ugz9yk1xxJIMnRDd8B14AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Cx-m7gQStpOWnFiSzLFdZ5Vqa0s',
#      'id': 'Ugz9yk1xxJIMnRDd8B14AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'i&#39;ve recently watched your Youtube video on why random generated numbers are not really random. I have a case that i&#39;ve been working on figuring out. There is a Game that produces decimal generated numbers randomly and the play is for you to predict the next number that it will generate like it gives out 2.92, 1.65, 1.04, 3.75, 6.73, 1.53 ...... it may even reach 10000.0 some times. Is there a way that i can use those previous generated numbers to predict the next numbers that it will generate?',
#       'textOriginal': "i've recently watched your Youtube video on why random generated numbers are not really random. I have a case that i've been working on figuring out. There is a Game that produces decimal generated numbers randomly and the play is for you to predict the next number that it will generate like it gives out 2.92, 1.65, 1.04, 3.75, 6.73, 1.53 ...... it may even reach 10000.0 some times. Is there a way that i can use those previous generated numbers to predict the next numbers that it will generate?",
#       'authorDisplayName': 'Michael Bashagi',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqOh1rL4lbFDmHsnEz79gBU0WCqh2KFdpDF_cvy1=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCJUIGLjVCw22-QM_XgBOcxA',
#       'authorChannelId': {'value': 'UCJUIGLjVCw22-QM_XgBOcxA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-27T04:55:09Z',
#       'updatedAt': '2023-05-27T04:55:09Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'BAXXF9gaUBd4GT7GV6jbcu7_914',
#    'id': 'Ugxpxtnvqbv9v0-LG9p4AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'oIiJT1MQxxtOffNLj0GPKJJ_yZ0',
#      'id': 'Ugxpxtnvqbv9v0-LG9p4AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'i tried to contact you via your email address but the email got bounced..',
#       'textOriginal': 'i tried to contact you via your email address but the email got bounced..',
#       'authorDisplayName': 'Michael Bashagi',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqOh1rL4lbFDmHsnEz79gBU0WCqh2KFdpDF_cvy1=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCJUIGLjVCw22-QM_XgBOcxA',
#       'authorChannelId': {'value': 'UCJUIGLjVCw22-QM_XgBOcxA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-27T04:53:56Z',
#       'updatedAt': '2023-05-27T04:53:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'szU6Yb86RTNMST3jJD0oWaDq2LI',
#    'id': 'UgyuN5IiWLc_hvo2koB4AaABAg',
#    'snippet': {'videoId': 'zsYIw6RXjfM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ImfKDSTTGjb4ULasAw8HsffGImI',
#      'id': 'UgyuN5IiWLc_hvo2koB4AaABAg',
#      'snippet': {'videoId': 'zsYIw6RXjfM',
#       'textDisplay': 'Hi @TechWithTim Please recommend a SAST &amp; DAST tool specifically for Python based web application. I am aware that for web application we can use any available tool, however I am curious for only Flask and Django based web application.',
#       'textOriginal': 'Hi @TechWithTim Please recommend a SAST & DAST tool specifically for Python based web application. I am aware that for web application we can use any available tool, however I am curious for only Flask and Django based web application.',
#       'authorDisplayName': 'Warloc Carlos',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqPgieFgezQ1IHiSHwb6NqXccFZZuTHhOuhpDsMM1A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCdoVGLqZcY2DF2d8NdmTqhQ',
#       'authorChannelId': {'value': 'UCdoVGLqZcY2DF2d8NdmTqhQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-26T22:27:48Z',
#       'updatedAt': '2023-05-26T22:27:48Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
for comment in comment_response['items']:
    print(comment['snippet']['topLevelComment']['snippet']['textOriginal'], '\n')
# Out:
# Rapidly build and deploy APIs in seconds with DreamFactory ! https://bit.ly/3M1TAP7
#
# not able to install flask tried changing the virtual environment as well
# someone if faced the same issue please help
#
# An API is just an interface of callable functions. It can be a code library that simplifies some complex tasks, a web API (which is what this video talks about) or a bunch of functions that a running process on your computer exposes for other programs to interact with
#
# Thanks so much
#
# Great video like always Tim 👍🏽🍷
#
# instead of saying "underscore underscore" you can say "dunder" which is double underscore
#
# vary good video... Thanks
#
# api is not only for database, can be instructing other devices to do something, might not even need a reply.
#
# Great vid thanks. I think you might have missed some info if you can confirm. When you demo the GET request you're using the id:123, however we don't set that up so we can't repeat the steps as you have as you have presumably already created a user in this scenario?
#
# Use fast api and create apis even faster
#
# Thank you  so much for  this video
#
# nice video and the beard suits you well.
#
# i tried the get part and got an error :
# The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# 6 Years experience in every aspect computing and technology but somehow I never came across API development, very interesting. I've just been calling and calling them but never writing them
#
# you got old but stil very good
#
# Why do we need to specify mathods = ["POST"] for create user method apart from signifying that we want to write to database? Is there an actual utility? As far as i understand this method would be able to do its job even if you hadn't specified method
#
# sir can you make a vid , about creating minecraft in python using ursina engine!
#
# i've recently watched your Youtube video on why random generated numbers are not really random. I have a case that i've been working on figuring out. There is a Game that produces decimal generated numbers randomly and the play is for you to predict the next number that it will generate like it gives out 2.92, 1.65, 1.04, 3.75, 6.73, 1.53 ...... it may even reach 10000.0 some times. Is there a way that i can use those previous generated numbers to predict the next numbers that it will generate?
#
# i tried to contact you via your email address but the email got bounced..
#
# Hi @TechWithTim Please recommend a SAST & DAST tool specifically for Python based web application. I am aware that for web application we can use any available tool, however I am curious for only Flask and Django based web application.

# %% [markdown]
# ## Статистика по определенному видео
# Последний метод в этом погружении в API YouTube — `.videos()`

# %%
video_request = youtube.videos().list(
    part = ['snippet', 'contentDetails', 'id', 'statistics'],
    id = 'zsYIw6RXjfM'
)

video_response = video_request.execute()
video_response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'dCKbW2gCpji-jfFNfKEQnzLubdw',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'ZvVJz_gLWQiInqcH0Ui-bFhxAVg',
#    'id': 'zsYIw6RXjfM',
#    'snippet': {'publishedAt': '2023-05-23T13:00:53Z',
#     'channelId': 'UC4JX40jDee_tINbkjycV4Sg',
#     'title': 'Create A Python API in 12 Minutes',
#     'description': 'Rapidly build and deploy APIs in seconds with DreamFactory ! https://bit.ly/3M1TAP7\n\nAre you learning programming and wondering what an API is? An API is an Application Programming Interface that allows different software or systems to communicate with one another. I\'ll show you how to whip up your very own API in just 10 minutes using Python and Flask. \n\nPost Man API Platform: \nhttps://www.postman.com/\n\nFix Pip (Windows): \nhttps://www.youtube.com/watch?v=AdUZArA-kZw&t=204s\n\nFix Pip (Mac): \nhttps://www.youtube.com/watch?v=E-WhAS6qzsU\n\n💻 Master Blockchain and Web 3.0 development today by using BlockchainExpert: 🔗 https://algoexpert.io/blockchain (Use code "tim" for a discount!)\n\n💻 Accelerate your software engineering career with ProgrammingExpert: 🔗 https://programmingexpert.io/tim (Use code "tim" for a discount!)\n\n🎬 Timestamps⏱️\n00:00 | What is an API?\n02:02 | Dependency Setup\n02:49 | Flask API Setup\n04:49 | HTTP Methods\n05:28 | GET Routes\n08:46 | POST Routes\n10:38 | Testing APIs\n11:42 | Next Steps \n\n◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️\n👕 Merchandise: 🔗 https://teespring.com/stores/tech-with-tim-merch-shop\n📸 Instagram: 🔗 https://www.instagram.com/tech_with_tim\n📱 Twitter: 🔗 https://twitter.com/TechWithTimm\n🔊 Discord: 🔗 https://discord.gg/twt\n📝 LinkedIn: 🔗 https://www.linkedin.com/in/tim-ruscica-82631b179/\n🌎 Website: 🔗 https://techwithtim.net\n📂 GitHub: 🔗 https://github.com/techwithtim\n\nOne-Time Donations: 💲 https://www.paypal.com/donate?hosted_button_id=CU9FV329ADNT8\nPatreon: 💲 https://www.patreon.com/techwithtim\n◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️\n\n⭐️ Tags ⭐️\n-Tech With Tim\n-Python\n-Programming\n\n⭐️ Hashtags ⭐️\n#techwithtim #python #coding',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Tech With Tim',
#     'tags': ['tech with tim',
#      'build your first api in 10 minutes',
#      'api python tutorial',
#      'rest api in hindi',
#      'fastapi in python',
#      'api python project',
#      'fastapi python',
#      'fastapi tutorial',
#      'api python',
#      'python fastapi tutorial',
#      'python api fastapi',
#      'python fastapi project',
#      'python fastapi web app',
#      'learn coding',
#      'api tutorial',
#      'python',
#      'coding in flow',
#      'build api from scratch',
#      'learn programming',
#      'computers',
#      'learn python',
#      'coding tutorials'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'Create A Python API in 12 Minutes',
#      'description': 'Rapidly build and deploy APIs in seconds with DreamFactory ! https://bit.ly/3M1TAP7\n\nAre you learning programming and wondering what an API is? An API is an Application Programming Interface that allows different software or systems to communicate with one another. I\'ll show you how to whip up your very own API in just 10 minutes using Python and Flask. \n\nPost Man API Platform: \nhttps://www.postman.com/\n\nFix Pip (Windows): \nhttps://www.youtube.com/watch?v=AdUZArA-kZw&t=204s\n\nFix Pip (Mac): \nhttps://www.youtube.com/watch?v=E-WhAS6qzsU\n\n💻 Master Blockchain and Web 3.0 development today by using BlockchainExpert: 🔗 https://algoexpert.io/blockchain (Use code "tim" for a discount!)\n\n💻 Accelerate your software engineering career with ProgrammingExpert: 🔗 https://programmingexpert.io/tim (Use code "tim" for a discount!)\n\n🎬 Timestamps⏱️\n00:00 | What is an API?\n02:02 | Dependency Setup\n02:49 | Flask API Setup\n04:49 | HTTP Methods\n05:28 | GET Routes\n08:46 | POST Routes\n10:38 | Testing APIs\n11:42 | Next Steps \n\n◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️\n👕 Merchandise: 🔗 https://teespring.com/stores/tech-with-tim-merch-shop\n📸 Instagram: 🔗 https://www.instagram.com/tech_with_tim\n📱 Twitter: 🔗 https://twitter.com/TechWithTimm\n🔊 Discord: 🔗 https://discord.gg/twt\n📝 LinkedIn: 🔗 https://www.linkedin.com/in/tim-ruscica-82631b179/\n🌎 Website: 🔗 https://techwithtim.net\n📂 GitHub: 🔗 https://github.com/techwithtim\n\nOne-Time Donations: 💲 https://www.paypal.com/donate?hosted_button_id=CU9FV329ADNT8\nPatreon: 💲 https://www.patreon.com/techwithtim\n◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️\n\n⭐️ Tags ⭐️\n-Tech With Tim\n-Python\n-Programming\n\n⭐️ Hashtags ⭐️\n#techwithtim #python #coding'},
#     'defaultAudioLanguage': 'en-CA'},
#    'contentDetails': {'duration': 'PT12M5S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '125510',
#     'likeCount': '3565',
#     'favoriteCount': '0',
#     'commentCount': '60'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %% [markdown]
# Теперь попробуем собрать информацию о всех наших десяти видео!

# %%
video_ids = []

for video in response_search['items']:
    video_ids.append(video['id']['videoId'])
    
print(video_ids)
# Out:
# ['zsYIw6RXjfM', '0sOvCWFmrtA', '0x0hOdvhCXU', 'hpc5jyVpUpw', 'qbLc5a9jdXo', '5ZMpbdK0uqU', 'fXa_2rllZTI', '-ykeT6kk4bk', '_k22Bs3zYyA', '-oPuGc05Lxs']

# %%
video_10_request = youtube.videos().list(
    part = ['snippet', 'contentDetails', 'id', 'statistics'],
    id = video_ids
)

video_10_response = video_10_request.execute()

# %%
video_10_response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'x9kf98Y2xR_q_b8PHafrG4By970',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'ZvVJz_gLWQiInqcH0Ui-bFhxAVg',
#    'id': 'zsYIw6RXjfM',
#    'snippet': {'publishedAt': '2023-05-23T13:00:53Z',
#     'channelId': 'UC4JX40jDee_tINbkjycV4Sg',
#     'title': 'Create A Python API in 12 Minutes',
#     'description': 'Rapidly build and deploy APIs in seconds with DreamFactory ! https://bit.ly/3M1TAP7\n\nAre you learning programming and wondering what an API is? An API is an Application Programming Interface that allows different software or systems to communicate with one another. I\'ll show you how to whip up your very own API in just 10 minutes using Python and Flask. \n\nPost Man API Platform: \nhttps://www.postman.com/\n\nFix Pip (Windows): \nhttps://www.youtube.com/watch?v=AdUZArA-kZw&t=204s\n\nFix Pip (Mac): \nhttps://www.youtube.com/watch?v=E-WhAS6qzsU\n\n💻 Master Blockchain and Web 3.0 development today by using BlockchainExpert: 🔗 https://algoexpert.io/blockchain (Use code "tim" for a discount!)\n\n💻 Accelerate your software engineering career with ProgrammingExpert: 🔗 https://programmingexpert.io/tim (Use code "tim" for a discount!)\n\n🎬 Timestamps⏱️\n00:00 | What is an API?\n02:02 | Dependency Setup\n02:49 | Flask API Setup\n04:49 | HTTP Methods\n05:28 | GET Routes\n08:46 | POST Routes\n10:38 | Testing APIs\n11:42 | Next Steps \n\n◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️\n👕 Merchandise: 🔗 https://teespring.com/stores/tech-with-tim-merch-shop\n📸 Instagram: 🔗 https://www.instagram.com/tech_with_tim\n📱 Twitter: 🔗 https://twitter.com/TechWithTimm\n🔊 Discord: 🔗 https://discord.gg/twt\n📝 LinkedIn: 🔗 https://www.linkedin.com/in/tim-ruscica-82631b179/\n🌎 Website: 🔗 https://techwithtim.net\n📂 GitHub: 🔗 https://github.com/techwithtim\n\nOne-Time Donations: 💲 https://www.paypal.com/donate?hosted_button_id=CU9FV329ADNT8\nPatreon: 💲 https://www.patreon.com/techwithtim\n◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️\n\n⭐️ Tags ⭐️\n-Tech With Tim\n-Python\n-Programming\n\n⭐️ Hashtags ⭐️\n#techwithtim #python #coding',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/zsYIw6RXjfM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Tech With Tim',
#     'tags': ['tech with tim',
#      'build your first api in 10 minutes',
#      'api python tutorial',
#      'rest api in hindi',
#      'fastapi in python',
#      'api python project',
#      'fastapi python',
#      'fastapi tutorial',
#      'api python',
#      'python fastapi tutorial',
#      'python api fastapi',
#      'python fastapi project',
#      'python fastapi web app',
#      'learn coding',
#      'api tutorial',
#      'python',
#      'coding in flow',
#      'build api from scratch',
#      'learn programming',
#      'computers',
#      'learn python',
#      'coding tutorials'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'Create A Python API in 12 Minutes',
#      'description': 'Rapidly build and deploy APIs in seconds with DreamFactory ! https://bit.ly/3M1TAP7\n\nAre you learning programming and wondering what an API is? An API is an Application Programming Interface that allows different software or systems to communicate with one another. I\'ll show you how to whip up your very own API in just 10 minutes using Python and Flask. \n\nPost Man API Platform: \nhttps://www.postman.com/\n\nFix Pip (Windows): \nhttps://www.youtube.com/watch?v=AdUZArA-kZw&t=204s\n\nFix Pip (Mac): \nhttps://www.youtube.com/watch?v=E-WhAS6qzsU\n\n💻 Master Blockchain and Web 3.0 development today by using BlockchainExpert: 🔗 https://algoexpert.io/blockchain (Use code "tim" for a discount!)\n\n💻 Accelerate your software engineering career with ProgrammingExpert: 🔗 https://programmingexpert.io/tim (Use code "tim" for a discount!)\n\n🎬 Timestamps⏱️\n00:00 | What is an API?\n02:02 | Dependency Setup\n02:49 | Flask API Setup\n04:49 | HTTP Methods\n05:28 | GET Routes\n08:46 | POST Routes\n10:38 | Testing APIs\n11:42 | Next Steps \n\n◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️\n👕 Merchandise: 🔗 https://teespring.com/stores/tech-with-tim-merch-shop\n📸 Instagram: 🔗 https://www.instagram.com/tech_with_tim\n📱 Twitter: 🔗 https://twitter.com/TechWithTimm\n🔊 Discord: 🔗 https://discord.gg/twt\n📝 LinkedIn: 🔗 https://www.linkedin.com/in/tim-ruscica-82631b179/\n🌎 Website: 🔗 https://techwithtim.net\n📂 GitHub: 🔗 https://github.com/techwithtim\n\nOne-Time Donations: 💲 https://www.paypal.com/donate?hosted_button_id=CU9FV329ADNT8\nPatreon: 💲 https://www.patreon.com/techwithtim\n◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️\n\n⭐️ Tags ⭐️\n-Tech With Tim\n-Python\n-Programming\n\n⭐️ Hashtags ⭐️\n#techwithtim #python #coding'},
#     'defaultAudioLanguage': 'en-CA'},
#    'contentDetails': {'duration': 'PT12M5S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '125510',
#     'likeCount': '3565',
#     'favoriteCount': '0',
#     'commentCount': '60'}},
#   {'kind': 'youtube#video',
#    'etag': '3U5P15_vIhdYNxyl7Qg__3vyB3I',
#    'id': '0sOvCWFmrtA',
#    'snippet': {'publishedAt': '2021-11-01T13:11:23Z',
#     'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#     'title': 'Python API Development - Comprehensive Course for Beginners',
#     'description': 'Learn Python API development in one of the most comprehensive courses ever on the topic. You will build a full-fledged API in Python using FastAPI. You will learn the fundamentals of API design including routes, serialization/deserialization, schema validation, and models. You will also learn about SQL, testing with pytest, and how to build out a CI/CD pipeline using GitHub actions.\n\n💻 Code: https://github.com/Sanjeev-Thiyagarajan/fastapi-course\n\n✏️ Course from Sanjeev Thiyagarajan. Check out his channel: https://www.youtube.com/channel/UC2sYgV-NV6S5_-pqLGChoNQ\n\n⭐️ Course Contents\n00:00 Intro\n06:33 Project Overview\n11:22 Mac Python Installation\n13:15 Mac VS Code install and setup\n16:37 Windows Python Installation\n18:30 Windows VS Code install and setup\n22:11 Python virtual Env Basics\n24:35 Virtual Env on windows\n28:56 Virtual Env on Mac\n34:17 Install dependencies w/ pip\n36:21 Starting FastAPI\n39:23 Path Operations\n53:22 Intro toman\n57:34 HTTP Requests\n1:07:29 Schema Validation with Pydantic\n1:22:45 CRUD Operations\n1:29:44 Storing in Array\n1:34:06 Creating\n1:38:15 Postman Collections & saving requests\n1:39:47 Retrieve One\n1:48:10 Path order Matters\n1:52:46 Changing response Status Codes\n2:01:49 Deleting\n2:10:31 Updating\n2:18:02 Automatic Documentation\n2:21:34 Python packages\n2:24:11 Database Intro\n2:28:54 Postgres Windows Install\n2:31:28 Postgres Mac Install\n2:34:26 Database Schema & Tables\n2:44:35 Managing Postgres with PgAdmin GUI\n3:12:10 Your first SQL Query\n3:19:43 Filter results with "where"\n3:22:55 SQL Operators\n3:26:38 IN\n3:28:07 Pattern matching with LIKE\n3:31:59 Ordering Results\n3:36:27 LIMIT & OFFSET\n3:39:21 Modifying Data\n3:53:48 Setup App Database\n3:58:21 Connecting to database w/ Python\n4:08:00 Database CRUD\n4:31:18 ORM intro\n4:35:33 SQLALCHEMY setup\n4:55:25 Adding CreatedAt Column\n5:00:59 Get All\n5:07:55 Create\n5:15:50 Get by ID\n5:19:50 Delete\n5:22:31 Update\n5:28:21 Pydantic vs ORM Models\n5:32:21 Pydantic Models Deep Dive\n5:38:57 Response Model\n5:50:08 Creating Users Table\n5:54:50 User Registration Path Operation\n6:03:27 Hashing Passwords\n6:08:49 Refractor Hashing Logic\n6:10:32 Get User by ID\n6:17:13 FastAPI Routers\n6:27:34 Router Prefix\n6:30:31 Router Tags\n6:32:49 JWT Token Basics\n6:47:03 Login Process  \n7:00:44 Creating Token\n7:09:58 OAuth2 PasswordRequestForm\n7:13:23 Verify user is Logged In\n7:25:21 Fixing Bugs\n7:27:59 Protecting Routes\n7:36:17 Test Expired Token\n7:38:13 Fetching User in Protected Routes\n7:42:44 Postman advanced Features\n7:50:33 SQL Relationship Basics\n7:54:59 Postgres Foreign Keys\n8:07:20 SQLAlchemy Foreign Keys\n8:13:40 Update Schema to include User\n8:17:59 Assigning Owner id when creating new\n8:21:01 Delete and Update only your own\n8:27:48 Only Retrieving Logged in User\'s\n8:33:37 Sqlalchemy Relationships\n8:38:32 Query Parameters\n8:50:46 Cleanup our main.py file\n8:53:53 Env Variables\n9:21:20 Vote/Like Theory\n9:26:36 Votes Table\n9:31:33 Votes Sqlalchemy\n9:34:11 Votes Route\n9:52:31 SQL Joins\n10:15:26 Joins in SqlAlchemy\n10:28:21 Get One with Joins\n10:30:18 What is a database migration tool\n10:33:45 Alembic Setup\n11:13:50 Disable SqlAlchemy create Engine\n11:14:28 What is CORS?\n11:23:38 Git PreReqs\n11:27:40 Git Install\n11:29:23 Github\n11:34:39 Heroku intro\n11:35:40 Create Heroku App\n11:40:21 Heroku procfile\n11:44:59 Adding a Postgres database\n11:48:42 Env Variables in Heroku\n11:58:59 Alembic migrations on Heroku Postgres instance\n12:02:52 Pushing changed to production\n12:05:04 Create an Ubuntu VM\n12:08:04 Update packages\n12:10:47 Install Python\n12:12:21 Install Postgres & setup password\n12:17:28 Postgres Config\n12:24:50 Create new user and setup python evironment\n12:34:06 Env Variables\n12:42:24 Alembic migrations on production database\n12:45:57 Gunicorn\n12:54:12 Creating a Systemd service\n13:04:45 NGINX\n13:10:45 Setting up Domain name\n13:15:19 SSL/HTTPS\n13 ...
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0sOvCWFmrtA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0sOvCWFmrtA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0sOvCWFmrtA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/0sOvCWFmrtA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/0sOvCWFmrtA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'freeCodeCamp.org',
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'Python API Development - Comprehensive Course for Beginners',
#      'description': 'Learn Python API development in one of the most comprehensive courses ever on the topic. You will build a full-fledged API in Python using FastAPI. You will learn the fundamentals of API design including routes, serialization/deserialization, schema validation, and models. You will also learn about SQL, testing with pytest, and how to build out a CI/CD pipeline using GitHub actions.\n\n💻 Code: https://github.com/Sanjeev-Thiyagarajan/fastapi-course\n\n✏️ Course from Sanjeev Thiyagarajan. Check out his channel: https://www.youtube.com/channel/UC2sYgV-NV6S5_-pqLGChoNQ\n\n⭐️ Course Contents\n00:00 Intro\n06:33 Project Overview\n11:22 Mac Python Installation\n13:15 Mac VS Code install and setup\n16:37 Windows Python Installation\n18:30 Windows VS Code install and setup\n22:11 Python virtual Env Basics\n24:35 Virtual Env on windows\n28:56 Virtual Env on Mac\n34:17 Install dependencies w/ pip\n36:21 Starting FastAPI\n39:23 Path Operations\n53:22 Intro toman\n57:34 HTTP Requests\n1:07:29 Schema Validation with Pydantic\n1:22:45 CRUD Operations\n1:29:44 Storing in Array\n1:34:06 Creating\n1:38:15 Postman Collections & saving requests\n1:39:47 Retrieve One\n1:48:10 Path order Matters\n1:52:46 Changing response Status Codes\n2:01:49 Deleting\n2:10:31 Updating\n2:18:02 Automatic Documentation\n2:21:34 Python packages\n2:24:11 Database Intro\n2:28:54 Postgres Windows Install\n2:31:28 Postgres Mac Install\n2:34:26 Database Schema & Tables\n2:44:35 Managing Postgres with PgAdmin GUI\n3:12:10 Your first SQL Query\n3:19:43 Filter results with "where"\n3:22:55 SQL Operators\n3:26:38 IN\n3:28:07 Pattern matching with LIKE\n3:31:59 Ordering Results\n3:36:27 LIMIT & OFFSET\n3:39:21 Modifying Data\n3:53:48 Setup App Database\n3:58:21 Connecting to database w/ Python\n4:08:00 Database CRUD\n4:31:18 ORM intro\n4:35:33 SQLALCHEMY setup\n4:55:25 Adding CreatedAt Column\n5:00:59 Get All\n5:07:55 Create\n5:15:50 Get by ID\n5:19:50 Delete\n5:22:31 Update\n5:28:21 Pydantic vs ORM Models\n5:32:21 Pydantic Models Deep Dive\n5:38:57 Response Model\n5:50:08 Creating Users Table\n5:54:50 User Registration Path Operation\n6:03:27 Hashing Passwords\n6:08:49 Refractor Hashing Logic\n6:10:32 Get User by ID\n6:17:13 FastAPI Routers\n6:27:34 Router Prefix\n6:30:31 Router Tags\n6:32:49 JWT Token Basics\n6:47:03 Login Process  \n7:00:44 Creating Token\n7:09:58 OAuth2 PasswordRequestForm\n7:13:23 Verify user is Logged In\n7:25:21 Fixing Bugs\n7:27:59 Protecting Routes\n7:36:17 Test Expired Token\n7:38:13 Fetching User in Protected Routes\n7:42:44 Postman advanced Features\n7:50:33 SQL Relationship Basics\n7:54:59 Postgres Foreign Keys\n8:07:20 SQLAlchemy Foreign Keys\n8:13:40 Update Schema to include User\n8:17:59 Assigning Owner id when creating new\n8:21:01 Delete and Update only your own\n8:27:48 Only Retrieving Logged in User\'s\n8:33:37 Sqlalchemy Relationships\n8:38:32 Query Parameters\n8:50:46 Cleanup our main.py file\n8:53:53 Env Variables\n9:21:20 Vote/Like Theory\n9:26:36 Votes Table\n9:31:33 Votes Sqlalchemy\n9:34:11 Votes Route\n9:52:31 SQL Joins\n10:15:26 Joins in SqlAlchemy\n10:28:21 Get One with Joins\n10:30:18 What is a database migration tool\n10:33:45 Alembic Setup\n11:13:50 Disable SqlAlchemy create Engine\n11:14:28 What is CORS?\n11:23:38 Git PreReqs\n11:27:40 Git Install\n11:29:23 Github\n11:34:39 Heroku intro\n11:35:40 Create Heroku App\n11:40:21 Heroku procfile\n11:44:59 Adding a Postgres database\n11:48:42 Env Variables in Heroku\n11:58:59 Alembic migrations on Heroku Postgres instance\n12:02:52 Pushing changed to production\n12:05:04 Create an Ubuntu VM\n12:08:04 Update packages\n12:10:47 Install Python\n12:12:21 Install Postgres & setup password\n12:17:28 Postgres Config\n12:24:50 Create new user and setup python evironment\n12:34:06 Env Variables\n12:42:24 Alembic migrations on production database\n12:45:57 Gunicorn\n12:54:12 Creating a Systemd service\n13:04:45 NGINX\n13:10:45 Setting up Domain name\n13:15:19 SSL/HTTPS\n1 ...
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT19H27S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1611342',
#     'likeCount': '43622',
#     'favoriteCount': '0',
#     'commentCount': '1718'}},
#   {'kind': 'youtube#video',
#    'etag': '211aeSNJ8nl_7sSOhOUMzaegh6M',
#    'id': '0x0hOdvhCXU',
#    'snippet': {'publishedAt': '2019-10-10T07:52:52Z',
#     'channelId': 'UCGuhp4lpQvK94ZC5kuOZbjA',
#     'title': 'Урок 4. Python. Быстрый старт. Изучаем API сервиса',
#     'description': 'Подробнее о курсе "Python. Полное руководство": https://webformyself.com/python/\n\nИтак, немного познакомившись с Python, можно переходить к небольшой практике и в оставшихся уроках мини-курса будет показано написание программы переводчика. Это достаточно простая, но вместе с тем полезная практичная программа. Для ее реализации потребуется сервис, позволяющий осуществлять перевод с английского языка и предоставляющий API для работы. \n\nВ качестве такового выбран ABBYY Lingvo. В уроке будет показана работа с API сервиса с помощью приложения Postman.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0x0hOdvhCXU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0x0hOdvhCXU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0x0hOdvhCXU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/0x0hOdvhCXU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/0x0hOdvhCXU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'WebForMySelf',
#     'tags': ['Python',
#      'уроки по python',
#      'уроки по python 3.7',
#      'уроки по python для начинающих',
#      'уроки по python 3',
#      'python быстрый старт',
#      'python скачать',
#      'python 3 уроки',
#      'язык python уроки',
#      'python уроки с нуля',
#      'python видео уроки',
#      'python онлайн уроки',
#      'python курс',
#      'webformyself python',
#      'python кудлай',
#      'Postman',
#      'python написание программы',
#      'python api',
#      'python api уроки'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Урок 4. Python. Быстрый старт. Изучаем API сервиса',
#      'description': 'Подробнее о курсе "Python. Полное руководство": https://webformyself.com/python/\n\nИтак, немного познакомившись с Python, можно переходить к небольшой практике и в оставшихся уроках мини-курса будет показано написание программы переводчика. Это достаточно простая, но вместе с тем полезная практичная программа. Для ее реализации потребуется сервис, позволяющий осуществлять перевод с английского языка и предоставляющий API для работы. \n\nВ качестве такового выбран ABBYY Lingvo. В уроке будет показана работа с API сервиса с помощью приложения Postman.'},
#     'defaultAudioLanguage': 'ru'},
#    'contentDetails': {'duration': 'PT12M15S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '58359',
#     'likeCount': '959',
#     'favoriteCount': '0',
#     'commentCount': '28'}},
#   {'kind': 'youtube#video',
#    'etag': 'jPnN2TJWV12bJCBCSOJxP6O4sr0',
#    'id': 'hpc5jyVpUpw',
#    'snippet': {'publishedAt': '2019-11-02T14:00:09Z',
#     'channelId': 'UCF1dnm4HfA9LYQo9fVU5RKQ',
#     'title': 'Working with APIs in Python - Code in 10 Minutes',
#     'description': 'In this video, I teach you the basics of APIs & how to work with them in Python.\n\n\n---\nGet access to full VideoLab courses at:\nhttps://www.bit.ly/vl-udemy\nhttps://www.skl.sh/2XcqMYV\n\nSign up to the VideoLab Digest to get exclusive content & deals:\nhttp://bit.ly/vl-digest\n\nThe VideoLab Community gives you a chance to collaborate with other developers, learn new skills, and build a solid developer network. You can join at: http://bit.ly/vl-community\n\nFor more courses & educational content, visit: \nhttp://www.bit.ly/vl-site\nhttp://www.bit.ly/videolab-yt (YouTube)\nhttp://www.bit.ly/videolab-tw (Twitter)\nhttp://www.bit.ly/videolab-ig (Instagram)\nhttp://bit.ly/videolab-fb (Facebook)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hpc5jyVpUpw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hpc5jyVpUpw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hpc5jyVpUpw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/hpc5jyVpUpw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/hpc5jyVpUpw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'VideoLab',
#     'tags': ['programming',
#      'education',
#      'course',
#      'python',
#      'wordpress',
#      'html',
#      'css',
#      'java',
#      'ruby',
#      'node',
#      'javascript',
#      'cpp',
#      'software',
#      'tech',
#      'technology',
#      'coding',
#      'development',
#      'discount',
#      'free',
#      'coupon',
#      'api',
#      'data science',
#      'request',
#      'requests'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Working with APIs in Python - Code in 10 Minutes',
#      'description': 'In this video, I teach you the basics of APIs & how to work with them in Python.\n\n\n---\nGet access to full VideoLab courses at:\nhttps://www.bit.ly/vl-udemy\nhttps://www.skl.sh/2XcqMYV\n\nSign up to the VideoLab Digest to get exclusive content & deals:\nhttp://bit.ly/vl-digest\n\nThe VideoLab Community gives you a chance to collaborate with other developers, learn new skills, and build a solid developer network. You can join at: http://bit.ly/vl-community\n\nFor more courses & educational content, visit: \nhttp://www.bit.ly/vl-site\nhttp://www.bit.ly/videolab-yt (YouTube)\nhttp://www.bit.ly/videolab-tw (Twitter)\nhttp://www.bit.ly/videolab-ig (Instagram)\nhttp://bit.ly/videolab-fb (Facebook)'}},
#    'contentDetails': {'duration': 'PT8M41S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '264052',
#     'likeCount': '4530',
#     'favoriteCount': '0',
#     'commentCount': '108'}},
#   {'kind': 'youtube#video',
#    'etag': 'JZzOmrfxt-HvqCKkCSVF1E4YRiw',
#    'id': 'qbLc5a9jdXo',
#    'snippet': {'publishedAt': '2020-11-19T20:27:58Z',
#     'channelId': 'UCZUyPT9DkJWmS_DzdOi7RIA',
#     'title': 'REST API Crash Course - Introduction + Full Python API Tutorial',
#     'description': '💯 FREE Courses (100+ hours) - https://calcur.tech/all-in-ones\n🐍 Python Course - https://calcur.tech/python-courses\n\nTimestamps:\n00:00 - Introduction\n05:15 - API App example\n09:15 - Why an API is important\n15:00 - HTTP methods\n16:45 - POST vs PUT\n20:56 - Consume the StackOverflow API\n27:44 - Setting up our own Python API\n31:13 - GET request setup\n32:04 - Database model setup for SQLAlchemy\n39:10 - GET data with query.all\n41:56 - GET data by ID with parameter\n44:19 - Developer tools network Intro\n45:03 - POST a new record\n47:15 - Postman Introduction\n49:21 - DELETE data\n51:46 - Conclusion\n\n✅ Data Structures & Algorithms - https://calcur.tech/dsa-youtube\n\n~~~~~~~~~~~~~~~ CONNECT ~~~~~~~~~~~~~~~\n\n✉️ Newsletter - https://calcur.tech/newsletter\n📸 Instagram - https://www.instagram.com/CalebCurry\n🐦 Twitter - https://twitter.com/calebCurry\n🔗 LinkedIn - https://www.linkedin.com/in/calebcurry\n▶️ Subscribe - http://calcur.tech/subscribe\n👨🏻\u200d🎓 Courses - https://www.codebreakthrough.com\n\n~~~~~~~~~~~~~~ SUPPORT ME  ~~~~~~~~~~~~~~\n\n↪ My Amazon Store - https://www.amazon.com/shop/calebcurry\n🅿 Patreon - http://calcur.tech/patreon-calebcurry\n🅖 GitHub Sponsors - https://github.com/sponsors/CalebCurry\nⓅ Paypal - http://paypal.me/calcur\n\n🅑 Bitcoin - 3HnF1SWTzo1dCU7RwFLhgk7SYiVfV37Pbq\n🅔 Eth - 0x350139af84b60d075a3a0379716040b63f6D3853\n📈 Buy Bitcoin - https://calcur.tech/crypto\nReserve the Ruby Steel crypto rewards card and get a $25 bonus (use affiliate code "Caleb") - https://calcur.tech/crypto\n\n#python',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qbLc5a9jdXo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qbLc5a9jdXo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qbLc5a9jdXo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/qbLc5a9jdXo/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/qbLc5a9jdXo/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Caleb Curry',
#     'tags': ['rest api',
#      'rest apis',
#      'python api',
#      'api introduction',
#      'flask rest api',
#      'python flask',
#      'get',
#      'post',
#      'put',
#      'delete',
#      'put vs post',
#      'post vs put',
#      'idempotent',
#      'sqlalchemy',
#      'python tutorial',
#      'rest api tutorial',
#      'what is rest api',
#      'rest api tutorial for beginners',
#      'restful api',
#      'python rest api',
#      'python rest api tutorial',
#      'rest api python',
#      'rest api python tutorial',
#      'flask api',
#      'what is an api',
#      'django rest framework'],
#     'categoryId': '28',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'REST API Crash Course - Introduction + Full Python API Tutorial',
#      'description': '💯 FREE Courses (100+ hours) - https://calcur.tech/all-in-ones\n🐍 Python Course - https://calcur.tech/python-courses\n\nTimestamps:\n00:00 - Introduction\n05:15 - API App example\n09:15 - Why an API is important\n15:00 - HTTP methods\n16:45 - POST vs PUT\n20:56 - Consume the StackOverflow API\n27:44 - Setting up our own Python API\n31:13 - GET request setup\n32:04 - Database model setup for SQLAlchemy\n39:10 - GET data with query.all\n41:56 - GET data by ID with parameter\n44:19 - Developer tools network Intro\n45:03 - POST a new record\n47:15 - Postman Introduction\n49:21 - DELETE data\n51:46 - Conclusion\n\n✅ Data Structures & Algorithms - https://calcur.tech/dsa-youtube\n\n~~~~~~~~~~~~~~~ CONNECT ~~~~~~~~~~~~~~~\n\n✉️ Newsletter - https://calcur.tech/newsletter\n📸 Instagram - https://www.instagram.com/CalebCurry\n🐦 Twitter - https://twitter.com/calebCurry\n🔗 LinkedIn - https://www.linkedin.com/in/calebcurry\n▶️ Subscribe - http://calcur.tech/subscribe\n👨🏻\u200d🎓 Courses - https://www.codebreakthrough.com\n\n~~~~~~~~~~~~~~ SUPPORT ME  ~~~~~~~~~~~~~~\n\n↪ My Amazon Store - https://www.amazon.com/shop/calebcurry\n🅿 Patreon - http://calcur.tech/patreon-calebcurry\n🅖 GitHub Sponsors - https://github.com/sponsors/CalebCurry\nⓅ Paypal - http://paypal.me/calcur\n\n🅑 Bitcoin - 3HnF1SWTzo1dCU7RwFLhgk7SYiVfV37Pbq\n🅔 Eth - 0x350139af84b60d075a3a0379716040b63f6D3853\n📈 Buy Bitcoin - https://calcur.tech/crypto\nReserve the Ruby Steel crypto rewards card and get a $25 bonus (use affiliate code "Caleb") - https://calcur.tech/crypto\n\n#python'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT52M50S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '683336',
#     'likeCount': '16737',
#     'favoriteCount': '0',
#     'commentCount': '591'}},
#   {'kind': 'youtube#video',
#    'etag': 'FqzsvRFVkorq930v65OjgshknCs',
#    'id': '5ZMpbdK0uqU',
#    'snippet': {'publishedAt': '2021-01-27T08:30:00Z',
#     'channelId': 'UCuudpdbKmQWq2PPzYgVCWlA',
#     'title': 'Create your own Public API in Python Tutorial',
#     'description': "Hey guys! In this video I'll be showing you how you can create your own API in Python. This is perfect for testing something on your app, website, or anything that uses an API. Let me know how it goes in the comment section!",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5ZMpbdK0uqU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5ZMpbdK0uqU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5ZMpbdK0uqU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/5ZMpbdK0uqU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/5ZMpbdK0uqU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Indently',
#     'tags': ['android studio',
#      'code',
#      'coding',
#      'program',
#      'programming',
#      'tutorials',
#      'android',
#      'studio',
#      'java',
#      'kotlin',
#      'python',
#      'c#',
#      'how to',
#      'app',
#      'applications',
#      'developer',
#      'developement',
#      'learn coding',
#      'learn programming',
#      'free',
#      'coding in flow',
#      'androidevs',
#      'code palace',
#      'windows',
#      'computers',
#      'ios',
#      'technology'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Create your own Public API in Python Tutorial',
#      'description': "Hey guys! In this video I'll be showing you how you can create your own API in Python. This is perfect for testing something on your app, website, or anything that uses an API. Let me know how it goes in the comment section!"},
#     'defaultAudioLanguage': 'en-GB'},
#    'contentDetails': {'duration': 'PT8M37S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '132379',
#     'likeCount': '2181',
#     'favoriteCount': '0',
#     'commentCount': '57'}},
#   {'kind': 'youtube#video',
#    'etag': 'aVHOLgRyv1_PM73nPJcxbIcsJVo',
#    'id': 'fXa_2rllZTI',
#    'snippet': {'publishedAt': '2022-06-02T13:45:01Z',
#     'channelId': 'UCSTYGpIpMIiQPspjLplB6Ow',
#     'title': 'Что такое API?',
#     'description': '👉 Получи высокооплачиваемые знания в Merion Academy!\nhttps://bit.ly/3taDcSE\n\nAPI расшифровывается как Application Programming Interface (программный интерфейс приложения), а в айти тусовке коротко называется "апи". По сути, это описание способов взаимодействия между программами, как они могут общаться и передавать данные друг другу.\n\nKeep calm and Merion ❤️\nhttps://wiki.merionet.ru/merion-academy?utm_source=YT&utm_medium=own&utm_campaign=api_video\n\nКреатив и анимация:\nhttps://instagram.com/cine.vibe\n\n#API #ApplicationProgrammingInterface #АПИ',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fXa_2rllZTI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fXa_2rllZTI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fXa_2rllZTI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/fXa_2rllZTI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/fXa_2rllZTI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Merion Academy - доступное IT образование',
#     'tags': ['api',
#      'Application Programming Interface',
#      'REST API',
#      'SOAP',
#      'Service Object Access Protocol',
#      'RESTful API',
#      'YAML',
#      'JSON',
#      'gRPC',
#      'gRPC Remote Procedure Calls',
#      'GraphQL',
#      'XML'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Что такое API?',
#      'description': '👉 Получи высокооплачиваемые знания в Merion Academy!\nhttps://bit.ly/3taDcSE\n\nAPI расшифровывается как Application Programming Interface (программный интерфейс приложения), а в айти тусовке коротко называется "апи". По сути, это описание способов взаимодействия между программами, как они могут общаться и передавать данные друг другу.\n\nKeep calm and Merion ❤️\nhttps://wiki.merionet.ru/merion-academy?utm_source=YT&utm_medium=own&utm_campaign=api_video\n\nКреатив и анимация:\nhttps://instagram.com/cine.vibe\n\n#API #ApplicationProgrammingInterface #АПИ'},
#     'defaultAudioLanguage': 'ru'},
#    'contentDetails': {'duration': 'PT6M5S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '214244',
#     'likeCount': '11576',
#     'favoriteCount': '0',
#     'commentCount': '295'}},
#   {'kind': 'youtube#video',
#    'etag': '2TjjaBoPFFMQRX8aWnm0ve2SE-o',
#    'id': '-ykeT6kk4bk',
#    'snippet': {'publishedAt': '2021-05-29T15:00:00Z',
#     'channelId': 'UC4JX40jDee_tINbkjycV4Sg',
#     'title': 'Python FAST API Tutorial',
#     'description': "Welcome back to my channel! In this video, I will be showing you FastAPI which is a Python framework. As the name suggests, this allows us to make APIs in Python.\n\n💻 Checkout Intel's OpenVINO toolkit for FREE and start building and deploying AI/ML applications with the DevCloud for the edge! https://intel.ly/3whdRWo #sponsored\n\n📄 Resources 📄\nFAST-API Docs: https://fastapi.tiangolo.com/\nFix Pip (Windows): https://www.youtube.com/watch?v=AdUZArA-kZw\nFix Pip (Mac/Linux): https://www.youtube.com/watch?v=E-WhAS6qzsU&t=4s\n\n⭐️ Timestamps ⭐️\n00:00 | Introduction\n02:22 | FAST-API Advantages\n04:49 | Installing FastAPI\n06:26 | Writing Our First FAST-API API\n10:58 | Running Our API\n14:00 | What is an API\n16:35 | JSON Explanation\n18:16 | Creating More Endpoints & GET Method\n19:19 | Path/Endpoint Parameters\n27:19 | Query Parameters\n35:19 | Request Body & POST Method\n44:12 | PUT Method\n50:42 | Delete Method\n53:15 | Status Codes and Error Responses\n\n◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️\n💰 Courses & Merch 💰 \n💻 The Fundamentals of Programming w/ Python: https://tech-with-tim.teachable.com/p/the-fundamentals-of-programming-with-python \n👕 Merchandise: https://teespring.com/stores/tech-with-tim-merch-shop \n\n🔗 Social Medias 🔗 \n📸 Instagram: https://www.instagram.com/tech_with_tim \n📱 Twitter: https://twitter.com/TechWithTimm \n⭐ Discord: https://discord.gg/twt\n📝 LinkedIn: https://www.linkedin.com/in/tim-ruscica-82631b179/ \n🌎 Website: https://techwithtim.net \n📂 GitHub: https://github.com/techwithtim \n🔊 Podcast: https://anchor.fm/tech-with-tim \n\n🎬 My YouTube Gear 🎬 \n🎥 Main Camera (EOS Canon 90D): https://amzn.to/3cY23y9 \n🎥 Secondary Camera (Panasonic Lumix G7): https://amzn.to/3fl2iEV \n📹 Main Lens (EFS 24mm f/2.8): https://amzn.to/2Yuol5r \n🕹 Tripod: https://amzn.to/3hpSprv \n🎤 Main Microphone (Rode NT1): https://amzn.to/2HrZxXc\n🎤 Secondary Microphone (Synco Wireless Lapel System): https://amzn.to/3e07Swl \n🎤 Third Microphone (Rode NTG4+): https://amzn.to/3oi0v8Z\n☀️ Lights: https://amzn.to/2ApeiXr \n⌨ Keyboard (Daskeyboard 4Q): https://amzn.to/2YpN5vm \n🖱 Mouse (Logitech MX Master): https://amzn.to/2HsmRDN\n📸 Webcam (Logitech 1080p Pro): https://amzn.to/2B2IXcQ \n📢 Speaker (Beats Pill): https://amzn.to/2XYc5ef \n🎧 Headphones (Bose Quiet Comfort 35): https://amzn.to/2MWbl3e \n🌞 Lamp (BenQ E-reading Lamp): https://amzn.to/3e0UCr8 \n🌞 Secondary Lamp (BenQ Screenbar Plus): https://amzn.to/30Dtafi \n💻 Monitor (BenQ EX2780Q): https://amzn.to/2HsmUPZ\n💻 Monitor (LG Ultrawide 34WN750): https://amzn.to/3dSD7tS\n🎙 Mic Boom Arm (Rode PSA 1): https://amzn.to/30EZw9m \n🎚 Audio Interface (Focusrite Scarlet 4i4): https://amzn.to/2TjXsih\n\n💸 Donations 💸 \n💵 One-Time Donations: https://www.paypal.com/donate?hosted_button_id=CU9FV329ADNT8\n💰 Patreon: https://www.patreon.com/techwithtim\n◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️\n\n⭐️ Tags ⭐️\n-Tech With Tim\n- Fast API\n- Fast API Tutorial\n- Python API\n- Python FastAPI Tutorial\n\n⭐️ Hashtags ⭐️\n#TechWithTiim #FastAPITutorial",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-ykeT6kk4bk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-ykeT6kk4bk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-ykeT6kk4bk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/-ykeT6kk4bk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/-ykeT6kk4bk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Tech With Tim',
#     'tags': ['tech with tim',
#      'tech with tim tutorial',
#      'fast api',
#      'fast api tutorial',
#      'python api',
#      'python fast api',
#      'python fast api tutorial',
#      'what is api',
#      'api tutorial',
#      'fastapi',
#      'fastapi tutorial',
#      'fastapi python',
#      'api python tutorial',
#      'api python',
#      'fastapi python tutorial',
#      'json',
#      'data validation',
#      'auto documentation',
#      'auto completion',
#      'code suggestions',
#      'endpoints',
#      'query parameters',
#      'post method',
#      'put method',
#      'delete method',
#      'installing fastapi',
#      'python json',
#      'what is json',
#      'json explained'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'Python FAST API Tutorial',
#      'description': "Welcome back to my channel! In this video, I will be showing you FastAPI which is a Python framework. As the name suggests, this allows us to make APIs in Python.\n\n💻 Checkout Intel's OpenVINO toolkit for FREE and start building and deploying AI/ML applications with the DevCloud for the edge! https://intel.ly/3whdRWo #sponsored\n\n📄 Resources 📄\nFAST-API Docs: https://fastapi.tiangolo.com/\nFix Pip (Windows): https://www.youtube.com/watch?v=AdUZArA-kZw\nFix Pip (Mac/Linux): https://www.youtube.com/watch?v=E-WhAS6qzsU&t=4s\n\n⭐️ Timestamps ⭐️\n00:00 | Introduction\n02:22 | FAST-API Advantages\n04:49 | Installing FastAPI\n06:26 | Writing Our First FAST-API API\n10:58 | Running Our API\n14:00 | What is an API\n16:35 | JSON Explanation\n18:16 | Creating More Endpoints & GET Method\n19:19 | Path/Endpoint Parameters\n27:19 | Query Parameters\n35:19 | Request Body & POST Method\n44:12 | PUT Method\n50:42 | Delete Method\n53:15 | Status Codes and Error Responses\n\n◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️\n💰 Courses & Merch 💰 \n💻 The Fundamentals of Programming w/ Python: https://tech-with-tim.teachable.com/p/the-fundamentals-of-programming-with-python \n👕 Merchandise: https://teespring.com/stores/tech-with-tim-merch-shop \n\n🔗 Social Medias 🔗 \n📸 Instagram: https://www.instagram.com/tech_with_tim \n📱 Twitter: https://twitter.com/TechWithTimm \n⭐ Discord: https://discord.gg/twt\n📝 LinkedIn: https://www.linkedin.com/in/tim-ruscica-82631b179/ \n🌎 Website: https://techwithtim.net \n📂 GitHub: https://github.com/techwithtim \n🔊 Podcast: https://anchor.fm/tech-with-tim \n\n🎬 My YouTube Gear 🎬 \n🎥 Main Camera (EOS Canon 90D): https://amzn.to/3cY23y9 \n🎥 Secondary Camera (Panasonic Lumix G7): https://amzn.to/3fl2iEV \n📹 Main Lens (EFS 24mm f/2.8): https://amzn.to/2Yuol5r \n🕹 Tripod: https://amzn.to/3hpSprv \n🎤 Main Microphone (Rode NT1): https://amzn.to/2HrZxXc\n🎤 Secondary Microphone (Synco Wireless Lapel System): https://amzn.to/3e07Swl \n🎤 Third Microphone (Rode NTG4+): https://amzn.to/3oi0v8Z\n☀️ Lights: https://amzn.to/2ApeiXr \n⌨ Keyboard (Daskeyboard 4Q): https://amzn.to/2YpN5vm \n🖱 Mouse (Logitech MX Master): https://amzn.to/2HsmRDN\n📸 Webcam (Logitech 1080p Pro): https://amzn.to/2B2IXcQ \n📢 Speaker (Beats Pill): https://amzn.to/2XYc5ef \n🎧 Headphones (Bose Quiet Comfort 35): https://amzn.to/2MWbl3e \n🌞 Lamp (BenQ E-reading Lamp): https://amzn.to/3e0UCr8 \n🌞 Secondary Lamp (BenQ Screenbar Plus): https://amzn.to/30Dtafi \n💻 Monitor (BenQ EX2780Q): https://amzn.to/2HsmUPZ\n💻 Monitor (LG Ultrawide 34WN750): https://amzn.to/3dSD7tS\n🎙 Mic Boom Arm (Rode PSA 1): https://amzn.to/30EZw9m \n🎚 Audio Interface (Focusrite Scarlet 4i4): https://amzn.to/2TjXsih\n\n💸 Donations 💸 \n💵 One-Time Donations: https://www.paypal.com/donate?hosted_button_id=CU9FV329ADNT8\n💰 Patreon: https://www.patreon.com/techwithtim\n◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️◼️\n\n⭐️ Tags ⭐️\n-Tech With Tim\n- Fast API\n- Fast API Tutorial\n- Python API\n- Python FastAPI Tutorial\n\n⭐️ Hashtags ⭐️\n#TechWithTiim #FastAPITutorial"},
#     'defaultAudioLanguage': 'en-CA'},
#    'contentDetails': {'duration': 'PT58M20S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '253550',
#     'likeCount': '6767',
#     'favoriteCount': '0',
#     'commentCount': '239'}},
#   {'kind': 'youtube#video',
#    'etag': '-6E25tcSs9D_ayQjbnBC72GxM08',
#    'id': '_k22Bs3zYyA',
#    'snippet': {'publishedAt': '2023-07-04T16:10:08Z',
#     'channelId': 'UCbjozK_PYCTLEluFlrJ8UZg',
#     'title': 'FULL STACK PYTHON Offline Training @ DURGASOFT',
#     'description': 'FULL STACK PYTHON Offline Training @ DURGASOFT\n==================================================\nFULL STACK PYTHON (Python (Core + Adv) / Django / Flask / REST API / Basics of UI & MySQL) Offline Training \n\nBy Mr. Mohan Reddy (10+ Yrs of Exp,.. & Real Time Expert)\n\nDate & Time: 10th July @11:30AM\n\nDuration: 4 Months\n\nCourse Content: https://bit.ly/3MFEJIL\n\nContact for More Info:\nEmail: durgasoftoffline@gmail.com\nPhone: +91 - 8852 8852 96/97/63/64\n\nYoutube Channel: Durga Software Solutions\n10000+ Technical Software Training Videos on all Technologies.\nJust Subscribe Link: https://www.youtube.com/durgasoftware\n\nTo get latest DURGASOFT updates on trending Technologies,\nPlease Subscribe to Our Telegram Channel:\nLINK: https://t.me/durgasoftupdates\n\n#DURGASOFTWARE #DURGASOFT #PYTHON',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_k22Bs3zYyA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_k22Bs3zYyA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_k22Bs3zYyA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/_k22Bs3zYyA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/_k22Bs3zYyA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Durga Software Solutions',
#     'tags': ['Python Online Training',
#      'Learn Python',
#      'Python Tutorial',
#      'python programming Tutorial',
#      'Python for Beginners',
#      'python Programming Language Tutorial',
#      'python examples',
#      'python Advanced Tutorial',
#      'python Tutorial for Beginners',
#      'python Tutorial for Beginners with examples',
#      'python Guide',
#      'python 3.0 Tutrials',
#      'python crash course'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'FULL STACK PYTHON Offline Training @ DURGASOFT',
#      'description': 'FULL STACK PYTHON Offline Training @ DURGASOFT\n==================================================\nFULL STACK PYTHON (Python (Core + Adv) / Django / Flask / REST API / Basics of UI & MySQL) Offline Training \n\nBy Mr. Mohan Reddy (10+ Yrs of Exp,.. & Real Time Expert)\n\nDate & Time: 10th July @11:30AM\n\nDuration: 4 Months\n\nCourse Content: https://bit.ly/3MFEJIL\n\nContact for More Info:\nEmail: durgasoftoffline@gmail.com\nPhone: +91 - 8852 8852 96/97/63/64\n\nYoutube Channel: Durga Software Solutions\n10000+ Technical Software Training Videos on all Technologies.\nJust Subscribe Link: https://www.youtube.com/durgasoftware\n\nTo get latest DURGASOFT updates on trending Technologies,\nPlease Subscribe to Our Telegram Channel:\nLINK: https://t.me/durgasoftupdates\n\n#DURGASOFTWARE #DURGASOFT #PYTHON'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT34S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '45',
#     'likeCount': '0',
#     'favoriteCount': '0',
#     'commentCount': '0'}},
#   {'kind': 'youtube#video',
#    'etag': 'AopqYU1vlUP4Yqp9KSOWACHEhHg',
#    'id': '-oPuGc05Lxs',
#    'snippet': {'publishedAt': '2021-06-20T17:00:00Z',
#     'channelId': 'UC8tgRQ7DOzAbn9L7zDL8mLg',
#     'title': 'Working With APIs in Python - Pagination and Data Extraction',
#     'description': 'In this video I will show you how to work with an API using Python to extract data. Using the requests module\nwe can request the data in JSON format and then parse it out. Each response comes with some extra info too that\nwe can use to work out how many pages we need to request and the total amount of items we should expect to get.\n\nWorking with APIs in Python is a core skill for any developer so hopefully you can use this video as a good learning\n\nresource and start requesting data from APIs in your own projects!\n\n\nSupport Me:\n\n# Amazon US: https://amzn.to/2OzqL1M\n# Amazon UK: https://amzn.to/2OYuMwo\n# Hosting: Digital Ocean: https://m.do.co/c/c7c90f161ff6\n# Gear Used: https://jhnwr.com/gear/ (NEW)\n# Patreon: https://www.patreon.com/johnwatsonrooney (NEW)\n\n\n-------------------------------------\nDisclaimer: These are affiliate links and as an Amazon Associate I earn from qualifying purchases\n-------------------------------------\n\n\n# timestamps\n\n\n00:00 - Intro\n00:56 - Endpoints\n03:42 - Code Example\n21:20 - Results and Outro',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-oPuGc05Lxs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-oPuGc05Lxs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-oPuGc05Lxs/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/-oPuGc05Lxs/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/-oPuGc05Lxs/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'John Watson Rooney',
#     'tags': ['working with apis in python',
#      'wokring with apis',
#      'python api',
#      'learn python',
#      'rest api python',
#      'rest api explained',
#      'get data from api',
#      'api pagination',
#      'api pagination python',
#      'api pagination example'],
#     'categoryId': '28',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Working With APIs in Python - Pagination and Data Extraction',
#      'description': 'In this video I will show you how to work with an API using Python to extract data. Using the requests module\nwe can request the data in JSON format and then parse it out. Each response comes with some extra info too that\nwe can use to work out how many pages we need to request and the total amount of items we should expect to get.\n\nWorking with APIs in Python is a core skill for any developer so hopefully you can use this video as a good learning\n\nresource and start requesting data from APIs in your own projects!\n\n\nSupport Me:\n\n# Amazon US: https://amzn.to/2OzqL1M\n# Amazon UK: https://amzn.to/2OYuMwo\n# Hosting: Digital Ocean: https://m.do.co/c/c7c90f161ff6\n# Gear Used: https://jhnwr.com/gear/ (NEW)\n# Patreon: https://www.patreon.com/johnwatsonrooney (NEW)\n\n\n-------------------------------------\nDisclaimer: These are affiliate links and as an Amazon Associate I earn from qualifying purchases\n-------------------------------------\n\n\n# timestamps\n\n\n00:00 - Intro\n00:56 - Endpoints\n03:42 - Code Example\n21:20 - Results and Outro'}},
#    'contentDetails': {'duration': 'PT22M36S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '62748',
#     'likeCount': '1815',
#     'favoriteCount': '0',
#     'commentCount': '103'}}],
#  'pageInfo': {'totalResults': 10, 'resultsPerPage': 10}}

# %% [markdown]
# ## Базовая обработка выгрузки из API
#
# Чтобы привести это все в относительно приличный вид, сделаем таблицу. Поможет нам в этом модуль pandas, нам понадобится только один метод — `json_normalize()`.

# %%
import pandas as pd
table = pd.json_normalize(video_10_response['items'])
table
# Out:
#             kind                         etag           id  \
# 0  youtube#video  ZvVJz_gLWQiInqcH0Ui-bFhxAVg  zsYIw6RXjfM
# 1  youtube#video  3U5P15_vIhdYNxyl7Qg__3vyB3I  0sOvCWFmrtA
# 2  youtube#video  211aeSNJ8nl_7sSOhOUMzaegh6M  0x0hOdvhCXU
# 3  youtube#video  jPnN2TJWV12bJCBCSOJxP6O4sr0  hpc5jyVpUpw
# 4  youtube#video  JZzOmrfxt-HvqCKkCSVF1E4YRiw  qbLc5a9jdXo
# 5  youtube#video  FqzsvRFVkorq930v65OjgshknCs  5ZMpbdK0uqU
# 6  youtube#video  aVHOLgRyv1_PM73nPJcxbIcsJVo  fXa_2rllZTI
# 7  youtube#video  2TjjaBoPFFMQRX8aWnm0ve2SE-o  -ykeT6kk4bk
# 8  youtube#video  -6E25tcSs9D_ayQjbnBC72GxM08  _k22Bs3zYyA
# 9  youtube#video  AopqYU1vlUP4Yqp9KSOWACHEhHg  -oPuGc05Lxs
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2023-05-23T13:00:53Z  UC4JX40jDee_tINbkjycV4Sg
# 1  2021-11-01T13:11:23Z  UC8butISFwT-Wl7EV0hUK0BQ
# 2  2019-10-10T07:52:52Z  UCGuhp4lpQvK94ZC5kuOZbjA
# 3  2019-11-02T14:00:09Z  UCF1dnm4HfA9LYQo9fVU5RKQ
# 4  2020-11-19T20:27:58Z  UCZUyPT9DkJWmS_DzdOi7RIA
# 5  2021-01-27T08:30:00Z  UCuudpdbKmQWq2PPzYgVCWlA
# 6  2022-06-02T13:45:01Z  UCSTYGpIpMIiQPspjLplB6Ow
# 7  2021-05-29T15:00:00Z  UC4JX40jDee_tINbkjycV4Sg
# 8  2023-07-04T16:10:08Z  UCbjozK_PYCTLEluFlrJ8UZg
# 9  2021-06-20T17:00:00Z  UC8tgRQ7DOzAbn9L7zDL8mLg
#
#                                        snippet.title  \
# 0                  Create A Python API in 12 Minutes
# 1  Python API Development - Comprehensive Course ...
# 2  Урок 4. Python. Быстрый старт. Изучаем API сер...
# 3   Working with APIs in Python - Code in 10 Minutes
# 4  REST API Crash Course - Introduction + Full Py...
# 5      Create your own Public API in Python Tutorial
# 6                                     Что такое API?
# 7                           Python FAST API Tutorial
# 8     FULL STACK PYTHON Offline Training @ DURGASOFT
# 9  Working With APIs in Python - Pagination and D...
#
#                                  snippet.description  \
# 0  Rapidly build and deploy APIs in seconds with ...
# 1  Learn Python API development in one of the mos...
# 2  Подробнее о курсе "Python. Полное руководство"...
# 3  In this video, I teach you the basics of APIs ...
# 4  💯 FREE Courses (100+ hours) - https://calcur.t...
# 5  Hey guys! In this video I'll be showing you ho...
# 6  👉 Получи высокооплачиваемые знания в Merion Ac...
# 7  Welcome back to my channel! In this video, I w...
# 8  FULL STACK PYTHON Offline Training @ DURGASOFT...
# 9  In this video I will show you how to work with...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/zsYIw6RXjfM/default.jpg
# 1  https://i.ytimg.com/vi/0sOvCWFmrtA/default.jpg
# 2  https://i.ytimg.com/vi/0x0hOdvhCXU/default.jpg
# 3  https://i.ytimg.com/vi/hpc5jyVpUpw/default.jpg
# 4  https://i.ytimg.com/vi/qbLc5a9jdXo/default.jpg
# 5  https://i.ytimg.com/vi/5ZMpbdK0uqU/default.jpg
# 6  https://i.ytimg.com/vi/fXa_2rllZTI/default.jpg
# 7  https://i.ytimg.com/vi/-ykeT6kk4bk/default.jpg
# 8  https://i.ytimg.com/vi/_k22Bs3zYyA/default.jpg
# 9  https://i.ytimg.com/vi/-oPuGc05Lxs/default.jpg
#
#    snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                               120                                 90  ...
# 1                               120                                 90  ...
# 2                               120                                 90  ...
# 3                               120                                 90  ...
# 4                               120                                 90  ...
# 5                               120                                 90  ...
# 6                               120                                 90  ...
# 7                               120                                 90  ...
# 8                               120                                 90  ...
# 9                               120                                 90  ...
#
#   contentDetails.duration  contentDetails.dimension  \
# 0                 PT12M5S                        2d
# 1                PT19H27S                        2d
# 2                PT12M15S                        2d
# 3                 PT8M41S                        2d
# 4                PT52M50S                        2d
# 5                 PT8M37S                        2d
# 6                  PT6M5S                        2d
# 7                PT58M20S                        2d
# 8                   PT34S                        2d
# 9                PT22M36S                        2d
#
#    contentDetails.definition contentDetails.caption  \
# 0                         hd                   true
# 1                         hd                  false
# 2                         hd                  false
# 3                         hd                  false
# 4                         hd                  false
# 5                         hd                  false
# 6                         hd                   true
# 7                         hd                   true
# 8                         hd                  false
# 9                         hd                  false
#
#    contentDetails.licensedContent  contentDetails.projection  \
# 0                            True                rectangular
# 1                            True                rectangular
# 2                           False                rectangular
# 3                            True                rectangular
# 4                            True                rectangular
# 5                            True                rectangular
# 6                           False                rectangular
# 7                            True                rectangular
# 8                            True                rectangular
# 9                            True                rectangular
#
#   statistics.viewCount  statistics.likeCount  statistics.favoriteCount  \
# 0               125510                  3565                         0
# 1              1611342                 43622                         0
# 2                58359                   959                         0
# 3               264052                  4530                         0
# 4               683336                 16737                         0
# 5               132379                  2181                         0
# 6               214244                 11576                         0
# 7               253550                  6767                         0
# 8                   45                     0                         0
# 9                62748                  1815                         0
#
#   statistics.commentCount
# 0                      60
# 1                    1718
# 2                      28
# 3                     108
# 4                     591
# 5                      57
# 6                     295
# 7                     239
# 8                       0
# 9                     103
#
# [10 rows x 40 columns]

# %%
table['statistics.viewCount'] = pd.to_numeric(table['statistics.viewCount'])

# %%
table.sort_values(by = 'statistics.viewCount', ascending = False)
# Out:
#             kind                         etag           id  \
# 1  youtube#video  3U5P15_vIhdYNxyl7Qg__3vyB3I  0sOvCWFmrtA
# 4  youtube#video  JZzOmrfxt-HvqCKkCSVF1E4YRiw  qbLc5a9jdXo
# 3  youtube#video  jPnN2TJWV12bJCBCSOJxP6O4sr0  hpc5jyVpUpw
# 7  youtube#video  2TjjaBoPFFMQRX8aWnm0ve2SE-o  -ykeT6kk4bk
# 6  youtube#video  aVHOLgRyv1_PM73nPJcxbIcsJVo  fXa_2rllZTI
# 5  youtube#video  FqzsvRFVkorq930v65OjgshknCs  5ZMpbdK0uqU
# 0  youtube#video  ZvVJz_gLWQiInqcH0Ui-bFhxAVg  zsYIw6RXjfM
# 9  youtube#video  AopqYU1vlUP4Yqp9KSOWACHEhHg  -oPuGc05Lxs
# 2  youtube#video  211aeSNJ8nl_7sSOhOUMzaegh6M  0x0hOdvhCXU
# 8  youtube#video  -6E25tcSs9D_ayQjbnBC72GxM08  _k22Bs3zYyA
#
#     snippet.publishedAt         snippet.channelId  \
# 1  2021-11-01T13:11:23Z  UC8butISFwT-Wl7EV0hUK0BQ
# 4  2020-11-19T20:27:58Z  UCZUyPT9DkJWmS_DzdOi7RIA
# 3  2019-11-02T14:00:09Z  UCF1dnm4HfA9LYQo9fVU5RKQ
# 7  2021-05-29T15:00:00Z  UC4JX40jDee_tINbkjycV4Sg
# 6  2022-06-02T13:45:01Z  UCSTYGpIpMIiQPspjLplB6Ow
# 5  2021-01-27T08:30:00Z  UCuudpdbKmQWq2PPzYgVCWlA
# 0  2023-05-23T13:00:53Z  UC4JX40jDee_tINbkjycV4Sg
# 9  2021-06-20T17:00:00Z  UC8tgRQ7DOzAbn9L7zDL8mLg
# 2  2019-10-10T07:52:52Z  UCGuhp4lpQvK94ZC5kuOZbjA
# 8  2023-07-04T16:10:08Z  UCbjozK_PYCTLEluFlrJ8UZg
#
#                                        snippet.title  \
# 1  Python API Development - Comprehensive Course ...
# 4  REST API Crash Course - Introduction + Full Py...
# 3   Working with APIs in Python - Code in 10 Minutes
# 7                           Python FAST API Tutorial
# 6                                     Что такое API?
# 5      Create your own Public API in Python Tutorial
# 0                  Create A Python API in 12 Minutes
# 9  Working With APIs in Python - Pagination and D...
# 2  Урок 4. Python. Быстрый старт. Изучаем API сер...
# 8     FULL STACK PYTHON Offline Training @ DURGASOFT
#
#                                  snippet.description  \
# 1  Learn Python API development in one of the mos...
# 4  💯 FREE Courses (100+ hours) - https://calcur.t...
# 3  In this video, I teach you the basics of APIs ...
# 7  Welcome back to my channel! In this video, I w...
# 6  👉 Получи высокооплачиваемые знания в Merion Ac...
# 5  Hey guys! In this video I'll be showing you ho...
# 0  Rapidly build and deploy APIs in seconds with ...
# 9  In this video I will show you how to work with...
# 2  Подробнее о курсе "Python. Полное руководство"...
# 8  FULL STACK PYTHON Offline Training @ DURGASOFT...
#
#                    snippet.thumbnails.default.url  \
# 1  https://i.ytimg.com/vi/0sOvCWFmrtA/default.jpg
# 4  https://i.ytimg.com/vi/qbLc5a9jdXo/default.jpg
# 3  https://i.ytimg.com/vi/hpc5jyVpUpw/default.jpg
# 7  https://i.ytimg.com/vi/-ykeT6kk4bk/default.jpg
# 6  https://i.ytimg.com/vi/fXa_2rllZTI/default.jpg
# 5  https://i.ytimg.com/vi/5ZMpbdK0uqU/default.jpg
# 0  https://i.ytimg.com/vi/zsYIw6RXjfM/default.jpg
# 9  https://i.ytimg.com/vi/-oPuGc05Lxs/default.jpg
# 2  https://i.ytimg.com/vi/0x0hOdvhCXU/default.jpg
# 8  https://i.ytimg.com/vi/_k22Bs3zYyA/default.jpg
#
#    snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 1                               120                                 90  ...
# 4                               120                                 90  ...
# 3                               120                                 90  ...
# 7                               120                                 90  ...
# 6                               120                                 90  ...
# 5                               120                                 90  ...
# 0                               120                                 90  ...
# 9                               120                                 90  ...
# 2                               120                                 90  ...
# 8                               120                                 90  ...
#
#   contentDetails.duration  contentDetails.dimension  \
# 1                PT19H27S                        2d
# 4                PT52M50S                        2d
# 3                 PT8M41S                        2d
# 7                PT58M20S                        2d
# 6                  PT6M5S                        2d
# 5                 PT8M37S                        2d
# 0                 PT12M5S                        2d
# 9                PT22M36S                        2d
# 2                PT12M15S                        2d
# 8                   PT34S                        2d
#
#    contentDetails.definition contentDetails.caption  \
# 1                         hd                  false
# 4                         hd                  false
# 3                         hd                  false
# 7                         hd                   true
# 6                         hd                   true
# 5                         hd                  false
# 0                         hd                   true
# 9                         hd                  false
# 2                         hd                  false
# 8                         hd                  false
#
#    contentDetails.licensedContent  contentDetails.projection  \
# 1                            True                rectangular
# 4                            True                rectangular
# 3                            True                rectangular
# 7                            True                rectangular
# 6                           False                rectangular
# 5                            True                rectangular
# 0                            True                rectangular
# 9                            True                rectangular
# 2                           False                rectangular
# 8                            True                rectangular
#
#   statistics.viewCount  statistics.likeCount  statistics.favoriteCount  \
# 1              1611342                 43622                         0
# 4               683336                 16737                         0
# 3               264052                  4530                         0
# 7               253550                  6767                         0
# 6               214244                 11576                         0
# 5               132379                  2181                         0
# 0               125510                  3565                         0
# 9                62748                  1815                         0
# 2                58359                   959                         0
# 8                   45                     0                         0
#
#   statistics.commentCount
# 1                    1718
# 4                     591
# 3                     108
# 7                     239
# 6                     295
# 5                      57
# 0                      60
# 9                     103
# 2                      28
# 8                       0
#
# [10 rows x 40 columns]
